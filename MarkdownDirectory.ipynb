# %% [markdown]
# # Data Compilation
# #### Lauren Meintzer
# --------

# %% [markdown]
# *Purpose*
# - The purpose of this project is to teach users how to condense the County Health Data set into a subset of variables to engage with the material. This page will navigate the audience through the JupyterLab software and provide steps for creating the subset.

# %% [markdown]
# *Scope*
# - After collecting data from various regions, states, and county's we are using this data to identify the correlation between the state of North Carolina and teen births using random samples from a public data set.
# ---

# %% [markdown]
# ## Getting Started

# %% [markdown]
# 1. First the user must download the most recent version of Anaconda and launch the JupyterLab software provided. [Link to Download Anaconda](https://unc-libraries-data.github.io/Python/Setup.html)
# 2. To access the files needed to create the subset, you need to visit the following [GitHub repository](https://github.com/Lauuren/ENGL105-Unit3). From here you should look through the READMe file and download the County Health Data.csv file found in the **datasets folder** of the repository
# ---

# %% [markdown]
# ## System Requirements

# %% [markdown]
# 1. After you downloaded the software and dataset, you need to import the County Health data csv `CountyHealthData_2014-2015.csv` into JupyterLab.
# 2. To run the program you must first import two panda packages that will allow the data to be read more efficiently. Run the following lines in your program to import the packages:
#
# ![MarkdownTry2.png](attachment:e0c80270-ba01-43b3-82cb-c04b841f0afb.png)

# %% [markdown]
# 3. After importing the packages you must also identify the dataframe variable that will allow you to work with the County Health data you imported. To do this, you will use the `pd.read_csv()` attribute to read the dataframe of the imported csv file.

# %% [markdown]
# ![MarkdownTry3.png](attachment:0f203799-8b1a-4250-90fc-00d915f142b6.png)

# %% [markdown]
# ----

# %% [markdown]
# ## Creating the Subset

# %% [markdown]
# 1. After following all the steps from above, you can start exploring the dataset by  identifying the attributes of the dataframe. Specifically, you can locate the shape and size of the data by using `df.shape` and `df.size` to make it easier to comprehend.
#
# ![MarkdownTry5.png](attachment:69a2edc3-1729-48e6-9806-b3492b3e4b0b.png)
#
# 2. Another command is the `.column` attribute that displays all the variables in the dataset. This is important for this project because the County Health Data is a large data set and for this project we will need to identify what variables to work with.
# 3. From this list I selected the **Teen births** and **State** columns to examine further. I used the `df.State.value_counts()` attribute, to select the state I wanted to work with. I chose NC as it provided the perfect amount of samples necessary to work with.
#
# ![MarkdownTry4.png](attachment:8e2804ed-4cd2-410d-a70c-426fb2de4b02.png)
#
# 4. Now that we have selected our variables, it is time to define the subset. We can do this by creating a new variable `NC_Subset` and setting the data frame to NC with a `True/False` statement.

# %% [markdown]
# `NC_subset = df[df["State"] == "NC"]`

# %% [markdown]
# 5. With this new subset, we can now use the `.loc` attribute to locate the **Teen births** variable and designate it as part of the new and condensed dataset.
#
# The image below depicts steps 4 and 5:

# %% [markdown]
# ![Screen Shot 2022-11-13 at 10.19.24 PM.png](attachment:2c4e6f7c-387d-4116-9c02-ccf5e206bbb2.png)

# %% [markdown]
# 6. Once we have the new dataset created, the final step is to export this as a csv file to make it more accessible to the common public:

# %%
NC_subset.to_csv("NC_subset.csv", index=False)

# %% [markdown]
# 7. After following all the steps, you have created the NC Subset that can also be found in the GitHub repository linked in the **Getting Started** section. This dataset has multiple uses, and for this project we used it to identify the number of teen births across NC and their counties.
